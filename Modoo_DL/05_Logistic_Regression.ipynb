# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## 5-1 Logistic Regression

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras as k
import matplotlib.pyplot as plt

# %%
x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

model = k.Sequential()
model.add(k.layers.Dense(units = 1, input_dim = 2))
model.add(k.layers.Activation('sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = k.optimizers.SGD(lr = 0.1), metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_data, y_data, epochs = 1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4453 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6338 - accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 2.8393 - accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0826 - accuracy: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4145 - accuracy: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9366 - accuracy: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.7191 - accuracy: 0.3333
# Epoch 8/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6566 - accuracy: 0.6667
# Epoch 9/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6371 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
xy = [[0,0]]

for i in np.arange(1,4,0.1):
    print((i-1)*100/3 // 1,'% ongoing...')
    for j in np.arange(1,6,0.1):
        if model.predict([[i,j]]) < 0.5:
            xy = np.append(xy,[[i,j]], axis = 0)
            
plt.figure(figsize = (5,5))
plt.xlim(1,6)
plt.ylim(1,6)
plt.plot(xy[:,0], xy[:,1], 'g.')
plt.plot(x_data[0:3,0], x_data[0:3,1], 'bo')
plt.plot(x_data[3:,0], x_data[3:,1], 'ro')
# Out:
# 0.0 % ongoing...
# 3.0 % ongoing...
# 6.0 % ongoing...
# 10.0 % ongoing...
# 13.0 % ongoing...
# 16.0 % ongoing...
# 20.0 % ongoing...
# 23.0 % ongoing...
# 26.0 % ongoing...
# 30.0 % ongoing...
# 33.0 % ongoing...
# 36.0 % ongoing...
# 40.0 % ongoing...
# 43.0 % ongoing...
# 46.0 % ongoing...
# 50.0 % ongoing...
# 53.0 % ongoing...
# 56.0 % ongoing...
# 60.0 % ongoing...
# 63.0 % ongoing...
# 66.0 % ongoing...
# 70.0 % ongoing...
# 73.0 % ongoing...
# 76.0 % ongoing...
# 80.0 % ongoing...
# 83.0 % ongoing...
# 86.0 % ongoing...
# 90.0 % ongoing...
# 93.0 % ongoing...
# 96.0 % ongoing...

# %%
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
a,*b, c = 1,2,3,4,5,6
def sum(a,b,*c): return a+b
sum(*b)
# Out:
# 5
